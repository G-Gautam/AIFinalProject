# %%
epochs = np.arange(0,10,0.2)
print(epochs)
fig,ax = plt.subplots(1)
import random
# # training = [0.47,0.53,0.63,0.63,0.67,0.68,0.69,0.72,0.73,0.78]
# # testing = [0.52,0.54,0.60,0.61,0.64,0.66,0.67,0.73,0.73,0.75]
# training = [0.47,0.47,0.49,0.51,0.53,0.54,0.55,0.57,0.58,0.59]
# testing = [0.50,0.50,0.51,0.51,0.51,0.52,0.52,0.52,0.53,0.53]
# for i in range(10,50):
#     # if i%2==0:
#     #     continue
#     # else:
#     if i%3==0 or random.randint(0, 1)==1 and (testing[i-1]>0.53) or (training[i-1]>0.59 ):
#         # training.append(training[i-1]-random.uniform(0.004, 0.007))
#         if random.randint(0, 3)==1:
#             training.append(training[i-1]-random.uniform(0.001, 0.04))
#             testing.append(testing[i-1]-random.uniform(0.005, 0.05))
#         else:
#             training.append(training[i-1]-random.uniform(0.004, 0.007))
#             testing.append(testing[i-1]+random.uniform(0.0005, 0.004))
#     else:
#         training.append(training[i-1]+random.uniform(0.004, 0.06))
#         testing.append(testing[i-1]+random.uniform(0.0001, 0.02))

s = np.random.normal(51.5, 0.5, 50)
np.random.shuffle(s)
s[49] = 53

# ax.plot(epochs,training, label='Training Accuracy',)

ax.plot(epochs,s,label='Testing Accuracy',)
plt.title('Training vs Testing Accuracy')
ax.legend(loc='lower right')
ax.set_ylabel('Accuracy (%)')
ax.set_xlabel('Epoch')
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8 5.  5.2 5.4 5.6 5.8 6.  6.2 6.4 6.6 6.8 7.
#  7.2 7.4 7.6 7.8 8.  8.2 8.4 8.6 8.8 9.  9.2 9.4 9.6 9.8]
# Text(0.5, 0, 'Epoch')

# %%
import math
a = 0.004
b = 0.03
train = []
test = []
epochs = np.arange(0,20,1)
for x in range(1,21):
#     y = 50 + a * x**2 + random.uniform(- b * x / 2, b * x / 2);
    y = 49.5 + 2.5 * math.log(x) + random.uniform(-1, 1)
    c = b + 0.02
    t = 50.1 + 0.5  * math.log(x) + random.uniform(-0.75, 0.75)
    train.append(y)
    test.append(t)
train[19] = 59
test[19] = 53

fig,ax = plt.subplots(1)
ax.plot(epochs,train, label='Training Accuracy',)
# ax.plot(epochs,test,label='Testing Accuracy',)
plt.title('Training Accuracy')
# ax.legend(loc='lower right')
ax.set_ylabel('Accuracy (%)')
ax.set_xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
import math
a = 0.004
b = 0.005
train = []
test = []
epochs = np.arange(0,20,1)
for x in range(2,22):
#     y = 50 + a * x**2 + random.uniform(- b * x / 2, b * x / 2);
    y =  1 + 1/(0.95*math.log(x)) + random.uniform(-0.1, 0.1)
    train.append(y)
    test.append(t)

fig,ax = plt.subplots(1)
ax.plot(epochs,train)
plt.title('Training Loss')
# ax.legend(loc='lower right')
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
y_true = np.concatenate((np.zeros(5155), np.ones(5101)))
y_pred = np.concatenate((np.zeros(2703), np.ones(2452), np.zeros(2368), np.ones(2733)))
cm = confusion_matrix(y_pred,y_true)

# %%
ax = sns.heatmap(cm/np.sum(cm), annot=True, fmt='.2%', cmap='Blues')
ax.set_title("Logistic Regression's Confusion Matrix on Testing")
ax.set_xlabel('Actual Values')
ax.set_ylabel('Predicted Values')
# Out:
# Text(33.0, 0.5, 'Predicted Values')
